# %% [markdown]
# # Test `load_rawdata.py`

# %%
# %run ../load_rawdata.py

# %%
data = read_axuv_raw(get_some_file())

# %%
data.head()
# Out:
#       time    CH1    CH2    CH3    CH4    CH5    CH6    CH7    CH8    CH9  \
# 0  0.00000 -0.003 -0.001  0.000 -0.003 -0.001 -0.004 -0.002 -0.003 -0.003
# 1  0.00002  0.001 -0.001 -0.004 -0.002 -0.001 -0.004 -0.002 -0.001 -0.001
# 2  0.00004  0.001 -0.004 -0.005 -0.001 -0.002 -0.004  0.000 -0.002 -0.002
# 3  0.00006  0.001 -0.004 -0.004 -0.002 -0.004 -0.003 -0.001 -0.002 -0.002
# 4  0.00008  0.001 -0.001 -0.003 -0.004 -0.004 -0.002 -0.002 -0.003 -0.003
#
#     CH10   CH11   CH12   CH13   CH14   CH15   CH16
# 0 -0.003 -0.003  0.001 -0.001  0.000 -0.657  0.001
# 1 -0.003 -0.001  0.000 -0.004 -0.001 -0.657  0.002
# 2 -0.003  0.000 -0.001  0.001 -0.001 -0.660  0.003
# 3 -0.005 -0.001 -0.004 -0.003 -0.001 -0.661  0.005
# 4 -0.001 -0.002 -0.002 -0.002 -0.001 -0.657 -0.002
